# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd

# %%
#definimos credenciales

client_id = 'b6841f7c97974c8aacbdf448dae8677f'
client_secret = 'bc15cade85bc41f88d451fbb2c832eff'
redirect_uri = 'http://localhost:8888/callback/'
scope = 'user-read-private'

# %%
#utilizamos spotipy para interactuar con la API de spotify para buscar cancciones
# obtener listas de reproduccion, reproducir musica, etc

sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=client_id,
        client_secret = client_secret,
        redirect_uri=redirect_uri,
        scope=scope
    )
)

# %%
#buscamos un artista por su nombre
artist = 'Taylor Swift'
results = sp.search(q = f'artist:{artist}', type='artist')

# %%
results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3ATaylor+Swift&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'followers': {'href': None, 'total': 123919312},
#     'genres': ['pop'],
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebe672b5f553298dcdccb0e676',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174e672b5f553298dcdccb0e676',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178e672b5f553298dcdccb0e676',
#       'width': 160}],
#     'name': 'Taylor Swift',
#     'popularity': 100,
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Yzz6SisIkcvuhKSdJ02en'},
#     'followers': {'href': None, 'total': 121},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5Yzz6SisIkcvuhKSdJ02en',
#     'id': '5Yzz6SisIkcvuhKSdJ02en',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273623c43e08dff5dce47beb004',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02623c43e08dff5dce47beb004',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851623c43e08dff5dce47beb004',
#       'width': 64}],
#     'name': 'Taylor Swifter',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:5Yzz6SisIkcvuhKSdJ02en'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DwbGCdaD8YLRiVUEiV70Q'},
#     'followers': {'href': None, 'total': 3873},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0DwbGCdaD8YLRiVUEiV70Q',
#     'id': '0DwbGCdaD8YLRiVUEiV70Q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738160a48bb1693050f496b11e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028160a48bb1693050f496b11e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518160a48bb1693050f496b11e',
#       'width': 64}],
#     'name': 'Taylor Swift Piano Covers',
#     'popularity': 33,
#     'type': 'artist',
#     'uri': 'spotify:artist:0DwbGCdaD8YLRiVUEiV70Q'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7kaJOOAkXnnaA7nlEb9p0H'},
#     'followers': {'href': None, 'total': 178},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7kaJOOAkXnnaA7nlEb9p0H',
#     'id': '7kaJOOAkXnnaA7nlEb9p0H',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d280a0345333842e408c03d1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d280a0345333842e408c03d1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d280a0345333842e408c03d1',
#       'width': 64}],
#     'name': 'Taylor Swifta',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:7kaJOOAkXnnaA7nlEb9p0H'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7oW3aIseIypoEqcOqvzUfS'},
#     'followers': {'href': None, 'total': 125},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7oW3aIseIypoEqcOqvzUfS',
#     'id': '7oW3aIseIypoEqcOqvzUfS',
#     'images': [],
#     'name': 'taylorr swiftt',
#     'popularity': 7,
#     'type': 'artist',
#     'uri': 'spotify:artist:7oW3aIseIypoEqcOqvzUfS'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/14waR9FpjuHkqhd3DlMAYu'},
#     'followers': {'href': None, 'total': 75},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/14waR9FpjuHkqhd3DlMAYu',
#     'id': '14waR9FpjuHkqhd3DlMAYu',
#     'images': [],
#     'name': 'Taylor Swiftsz',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:14waR9FpjuHkqhd3DlMAYu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3OGj4jFXF7Cw4ORWS7T3ra'},
#     'followers': {'href': None, 'total': 551},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3OGj4jFXF7Cw4ORWS7T3ra',
#     'id': '3OGj4jFXF7Cw4ORWS7T3ra',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bbd79a349857d5e5ec3f88d0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bbd79a349857d5e5ec3f88d0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bbd79a349857d5e5ec3f88d0',
#       'width': 64}],
#     'name': 'Taylor Swift Facts',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:3OGj4jFXF7Cw4ORWS7T3ra'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bgoHMYkNqVC9PTOrQECts'},
#     'followers': {'href': None, 'total': 456},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1bgoHMYkNqVC9PTOrQECts',
#     'id': '1bgoHMYkNqVC9PTOrQECts',
#     'images': [],
#     'name': 'Ed Sheeran Taylor Swift',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:1bgoHMYkNqVC9PTOrQECts'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vZoN5cnYOycsJ5KsFkjo5'},
#     'followers': {'href': None, 'total': 192},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3vZoN5cnYOycsJ5KsFkjo5',
#     'id': '3vZoN5cnYOycsJ5KsFkjo5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273785702c6f41f1fa6d6c3d2b1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02785702c6f41f1fa6d6c3d2b1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851785702c6f41f1fa6d6c3d2b1',
#       'width': 64}],
#     'name': 'Taylor Swift - Evermore - Piano Covers',
#     'popularity': 5,
#     'type': 'artist',
#     'uri': 'spotify:artist:3vZoN5cnYOycsJ5KsFkjo5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/75xajtqlPSZfqpy29CcGT9'},
#     'followers': {'href': None, 'total': 181},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/75xajtqlPSZfqpy29CcGT9',
#     'id': '75xajtqlPSZfqpy29CcGT9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737e3a27b3ac512860386631c0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027e3a27b3ac512860386631c0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517e3a27b3ac512860386631c0',
#       'width': 64}],
#     'name': 'The Taylor Swift Piano Cover Band',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:75xajtqlPSZfqpy29CcGT9'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=artist%3ATaylor+Swift&type=artist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 12}}

# %%
#obtenemos el ID del primer artista en los resultados
if not results['artists']['items']:
    print('No se encuentra disponible el artista.')

else:
    artist_id = results['artists']['items'][0]['id'] #nos muestra el id del artista buscado

    #obtenemos todos los albumes del artista
    albums = sp.artist_albums(
        artist_id,
        album_type='album',
        limit=50
    )

    artist_info = sp.artist(artist_id)
    followers_count = artist_info['followers']['total']  # Número de seguidores


    
    #lista para almaceenar todas las canciones y albumes
    all_songs = []

    #iteramos para recorrer cada album de la lista
    for album in albums['items']:
        #album_image_url = album['images'][0]['url'] if album['images'] else None
        songs = sp.album_tracks(album['id'])['items']
        for song in songs:
            song_info = sp.track(song['id'])
            all_songs.append(
                {
                    'album':album['name'],
                    'release_date':album['release_date'],
                    'songs': song['name'],
                    'song_duration': song['duration_ms'] / 1000,
                    'followers': followers_count,
                    'popularity_song': song_info['popularity']
                    
                    
                }
            )

        # all_songs.append(
        #     {
        #         'album':album['name'],
        #         'id':album['id'],
        #         'release_date':album['release_date'],
        #         'url_portada': album_image_url
        #     }
        # )

# %%
albums = pd.DataFrame(all_songs)
albums
# Out:
#                                             album release_date  \
# 0    THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19
# 1    THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19
# 2    THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19
# 3    THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19
# 4    THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19
# ..                                            ...          ...
# 577                 Taylor Swift (Deluxe Edition)   2006-10-24
# 578                 Taylor Swift (Deluxe Edition)   2006-10-24
# 579                 Taylor Swift (Deluxe Edition)   2006-10-24
# 580                 Taylor Swift (Deluxe Edition)   2006-10-24
# 581                 Taylor Swift (Deluxe Edition)   2006-10-24
#
#                                     songs  song_duration  followers  \
# 0           Fortnight (feat. Post Malone)        228.965  123919312
# 1           The Tortured Poets Department        293.048  123919312
# 2    My Boy Only Breaks His Favorite Toys        203.801  123919312
# 3                                Down Bad        261.228  123919312
# 4                         So Long, London        262.974  123919312
# ..                                    ...            ...        ...
# 577                              Our Song        201.106  123919312
# 578         I'm Only Me When I'm With You        213.053  123919312
# 579                             Invisible        203.226  123919312
# 580                A Perfectly Good Heart        220.146  123919312
# 581  Teardrops on My Guitar - Pop Version        179.066  123919312
#
#      popularity_song
# 0                 75
# 1                 73
# 2                 75
# 3                 75
# 4                 75
# ..               ...
# 577               61
# 578               52
# 579               50
# 580               49
# 581               52
#
# [582 rows x 6 columns]
